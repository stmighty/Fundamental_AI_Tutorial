# %% [markdown]
# # Assignment - Basic Pandas
# <sup>Created by Natawut Nupairoj, Department of Computer Engineering, Chulalongkorn University</sup>
#
# Using pandas to explore youtube trending data from GB (GBvideos.csv and GB_category_id.json) and answer the questions.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# To simplify data retrieval process on Colab, we heck if we are in the Colab environment and download data files from a shared drive and save them in folder "data".
#
# For those using jupyter notebook on the local computer, you can read data directly assuming you save data in the folder "data".

# %%
# for colab
"""

import sys
import subprocess

# Check if running on Google Colab
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # Specific commands for Google Colab
    # !wget https://github.com/kaopanboonyuen/2110446_DataScience_2021s2/raw/main/datasets/data.tgz -O data.tgz
    # !tar -xzvf data.tgz
else:
    # Commands for local machine, such as VSCode
    subprocess.run(["wget", "https://github.com/kaopanboonyuen/2110446_DataScience_2021s2/raw/main/datasets/data.tgz", "-O", "data.tgz"], check=True)
    subprocess.run(["tar", "-xzvf", "data.tgz"], check=True)
"""
# Out:
# '\n\nimport sys\nimport subprocess\n\n# Check if running on Google Colab\nIN_COLAB = \'google.colab\' in sys.modules\n\nif IN_COLAB:\n    # Specific commands for Google Colab\n    !wget https://github.com/kaopanboonyuen/2110446_DataScience_2021s2/raw/main/datasets/data.tgz -O data.tgz\n    !tar -xzvf data.tgz\nelse:\n    # Commands for local machine, such as VSCode\n    subprocess.run(["wget", "https://github.com/kaopanboonyuen/2110446_DataScience_2021s2/raw/main/datasets/data.tgz", "-O", "data.tgz"], check=True)\n    subprocess.run(["tar", "-xzvf", "data.tgz"], check=True)\n'

# %% [markdown]
# ## How many rows are there in the GBvideos.csv after removing duplications?

# %% [markdown]
# https://sparkbyexamples.com/pandas/pandas-find-unique-values-from-columns/
#
# https://www.geeksforgeeks.org/python-pandas-dataframe-drop_duplicates/

# %%
df = pd.read_csv('./data/GBvideos.csv')
df
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %% [markdown]
# ## 1. df.shape and .unique() for counting number of unique value for each column

# %%
df.shape
# Out:
# (38916, 16)

# %%
print(df['video_id'])
print(len(df['video_id']))
# Out:
# 0        Jw1Y-zhQURU
# 1        3s1rvMFUweQ
# 2        n1WpP7iowLc
# 3        PUTEiSjKwJU
# 4        rHwDegptbI4
#             ...
# 38911    l884wKofd54
# 38912    IP8k2xkhOdI
# 38913    Il-an3K9pjg
# 38914    -DRsfNObKIQ
# 38915    4YFo4bdMO8Q
# Name: video_id, Length: 38916, dtype: object
# 38916

# %%
print(df['video_id'].unique())
print(len(df['video_id'].unique()))
# Out:
# ['Jw1Y-zhQURU' '3s1rvMFUweQ' 'n1WpP7iowLc' ... 'V15BYnSr0P8' 'BOhylL90UVQ'
#  '14G7Qw5DC9M']
# 3272

# %%
df_noduplicate = df.drop_duplicates()
df_noduplicate
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
df_noduplicate.shape
# Out:
# (38745, 16)

# %% [markdown]
# ## 2. value counts and nan value

# %%
df_noduplicate['category_id'].value_counts()
# Out:
# category_id
# 10    13700
# 24     9055
# 22     2923
# 1      2564
# 26     1928
# 17     1903
# 23     1820
# 20     1778
# 25     1218
# 15      533
# 28      516
# 27      457
# 2       144
# 19       96
# 29       90
# 43       20
# Name: count, dtype: int64

# %%
print(type(df_noduplicate['category_id'].value_counts()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.isna().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               612
# dtype: int64

# %% [markdown]
# ## 3. statistic value

# %%
print(df_noduplicate['views'].mean())
print(df_noduplicate['views'].sum())
print(df_noduplicate['views'].min())
print(df_noduplicate['views'].max())
print(df_noduplicate['views'].mode())
# Out:
# 5911292.647515808
# 229033033628
# 851
# 424538912
# 0    191321
# Name: views, dtype: int64

# %%
print(df_noduplicate['views'].idxmin())
print(df_noduplicate['views'].idxmax())
# Out:
# 3477
# 28412

# %% [markdown]
# ## 4. loc and iloc

# %% [markdown]
# first index filter row, second filter column

# %%
df_noduplicate.iloc[:, 3:7]
# Out:
#                     channel_title  category_id              publish_time  \
# 0                      John Lewis           26  2017-11-10T07:38:29.000Z
# 1             Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                      EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3      Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4                Cute Girl Videos           25  2017-11-13T01:45:13.000Z
# ...                           ...          ...                       ...
# 38911         EnriqueIglesiasVEVO           10  2018-05-09T07:00:01.000Z
# 38912             Jacob Sartorius           10  2018-05-11T17:09:16.000Z
# 38913                  Anne-Marie           10  2018-05-08T11:05:08.000Z
# 38914     Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# 38915              SuperDuperKyle           10  2018-05-11T04:06:35.000Z
#
#                                                     tags
# ...

# %%
df_noduplicate.loc[:, ['channel_title', 'publish_time']]
# Out:
#                     channel_title              publish_time
# 0                      John Lewis  2017-11-10T07:38:29.000Z
# 1             Saturday Night Live  2017-11-12T06:24:44.000Z
# 2                      EminemVEVO  2017-11-10T17:00:03.000Z
# 3      Salford City Football Club  2017-11-13T02:30:38.000Z
# 4                Cute Girl Videos  2017-11-13T01:45:13.000Z
# ...                           ...                       ...
# 38911         EnriqueIglesiasVEVO  2018-05-09T07:00:01.000Z
# 38912             Jacob Sartorius  2018-05-11T17:09:16.000Z
# 38913                  Anne-Marie  2018-05-08T11:05:08.000Z
# 38914     Eurovision Song Contest  2018-05-08T20:32:32.000Z
# 38915              SuperDuperKyle  2018-05-11T04:06:35.000Z
#
# [38745 rows x 2 columns]

# %% [markdown]
# ## 5. filter by condition and drop_duplicates
#
# ||.     How many VDO's that contain at least one record (row) of "dislikes" more than "likes"?  <font color=red>DO NOT group by the data and make sure that you count only unique title!</font>

# %% [markdown]
# <font color=red>most of methods in dataframe are not replace old value you need to use new dataframe to store the value or you need to assign value to your datafame or you can use inplace=True!</font>

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-drop_duplicates/

# %%
len(df['title'].unique())
# Out:
# 3369

# %%
import pandas as pd
filtered_df = df[df['dislikes'] > df['likes']]

unique_videos_df = filtered_df.drop_duplicates(subset='title')

print(unique_videos_df.shape)
print(unique_videos_df.shape[0])
# Out:
# (56, 16)
# 56

# %% [markdown]
# ## How many VDO that are trending on 22 Jan 2018 with comments more than 10,000 comments?

# %% [markdown]
# search command : pandas dataframe filter by condition
#
# link : https://sparkbyexamples.com/pandas/pandas-filter-rows-by-conditions/

# %%
print(type(df['trending_date'][0]))
print(type(df['comment_count'][0]))
# Out:
# <class 'str'>
# <class 'numpy.int64'>

# %%
df_t_10000 = df.loc[(df['trending_date'] == '18.22.01') & (df['comment_count'] > 10000)]
df_t_10000
# Out:
#           video_id trending_date  \
# 13392  WAwRrtH-4Lg      18.22.01
# 13394  Y-iFgDK_D5s      18.22.01
# 13397  lrWRy9BBp-c      18.22.01
# 13398  _7985zBEM3o      18.22.01
# 13411  liczsmUSMA4      18.22.01
# 13416  M4vnmgZLA8s      18.22.01
# 13421  sGIm0-dQd8M      18.22.01
# 13427  eACohWVwTOc      18.22.01
# 13442  oRSVrtKph_k      18.22.01
# 13452  aMcjxSThD54      18.22.01
# 13457  V0HCZ4YGqbw      18.22.01
# 13470  S0nbOenwCLw      18.22.01
# 13480  M1fKcktiPuk      18.22.01
# 13484  uexk7jWXYmU      18.22.01
# 13508  yHHnywiSwIE      18.22.01
# 13513  Xo8FPXlI3CU      18.22.01
# 13515  ijUK3z5rt5s      18.22.01
# 13525  Mgfe5tIwOj0      18.22.01
# 13530  I5uXtODq74w      18.22.01
# 13531  dfnCAmr569k      18.22.01
# 13533  gu9_m0vm7fM      18.22.01
# 13536  b7K_lbglfI4      18.22.01
# 13546  FVRPzwb1Vi4      18.22.01
# 13547  YXTzMOmmEfE      18.22.01
# 13553  I7B0z_2EZmQ      18.22.01
# 13559  wQ_POfToaVY      18.22.01
# 13563  lVNt1sUWyDU      18.22.01
# ...

# %%
df_t_10000.shape
# Out:
# (28, 16)

# %%
df_t_10000.shape[0]
# Out:
# 28

# %% [markdown]
# ## 6. using group by -> for operation ex. sum, avg

# %%
df_try = df.loc[(df['trending_date'] == '17.01.12') ]
df_try
# Out:
#          video_id trending_date  \
# 3398  6ZfuNTqbHE8      17.01.12
# 3399  nx1R-eHSkfM      17.01.12
# 3400  8z_cg5CypRc      17.01.12
# 3401  WeyLEe1T0yo      17.01.12
# 3402  7AXo-bYGXI4      17.01.12
# ...           ...           ...
# 3591  hq9SEUlkZ5s      17.01.12
# 3592  lMSHTnkVJVs      17.01.12
# 3593  1ihTE5cxUCQ      17.01.12
# 3594  coOKvrsmQiI      17.01.12
# 3595  X9Gc_g638C8      17.01.12
#
#                                                   title  \
# 3398  Marvel Studios' Avengers: Infinity War Officia...
# 3399                     The New Snapchat in 60 Seconds
# 3400                     Kelly Clarkson Carpool Karaoke
# 3401       Why cities are full of uncomfortable benches
# 3402         Sam Smith - One Last Song (Official Video)
# ...                                                 ...
# 3591           My Very POSITIVE Birth Plan | MOTHERHOOD
# 3592                  Rae Sremmurd - Perplexing Pegasus
# 3593                   Charles Manson  - Cease To Exist
# ...

# %%
df_group = df.groupby('trending_date')
df_group.first().head()
# Out:
#                   video_id                                              title  \
# trending_date
# 17.01.12       6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 17.02.12       6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 17.03.12       SA7AIQw-7Ms         G-Eazy & Halsey - Him & I (Official Video)
# 17.04.12       1l26UFQ06eQ                              Welcome to Hell - SNL
# 17.05.12       dsNNfiA6qjs  Nick Crompton - JAKE PAUL, TEAM 10 & MARTINEZ ...
#
#                       channel_title  category_id              publish_time  \
# trending_date
# 17.01.12       Marvel Entertainment           24  2017-11-29T13:26:24.000Z
# 17.02.12       Marvel Entertainment           24  2017-11-29T13:26:24.000Z
# 17.03.12             GEazyMusicVEVO           10  2017-12-01T16:15:00.000Z
# 17.04.12        Saturday Night Live           24  2017-12-03T05:52:22.000Z
# 17.05.12                     Caspar           24  2017-12-04T18:58:55.000Z
#
# ...

# %%
df_group.last().head()
# Out:
#                   video_id                                              title  \
# trending_date
# 17.01.12       X9Gc_g638C8  BTS Talks Emojis and More at the 2017 AMAs | E...
# 17.02.12       8mCcM-PUmLM                         I Dressed Like It Was 1977
# 17.03.12       jpl2X8tDfIA              Are you really surprised you're here?
# 17.04.12       _akwfRuL4os  Highlights of the EA predatory behavior announ...
# 17.05.12       RP3UsFrDJfY  Lady Gaga - The Cure (Live On The American Mus...
#
#                              channel_title  category_id  \
# trending_date
# 17.01.12       E! Live from the Red Carpet           24
# 17.02.12                    Safiya Nygaard           22
# 17.03.12                             Wiggy           10
# 17.04.12                         Chris Lee           22
# 17.05.12                      LadyGagaVEVO           10
#
#                            publish_time  \
# trending_date
# 17.01.12       2017-11-20T03:14:59.000Z
# ...

# %%
print(type(df_group))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %% [markdown]
# Which date that has the minimum average number of comments per VDO?

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-groupby/

# %%
# Calculating the average number of comments per video for each trending date
average_comments = df.groupby('trending_date')['comment_count'].mean()

# Finding the trending date with the minimum average number of comments
min_average_date = average_comments.idxmin()
min_average_value = average_comments.min()

min_average_date, min_average_value
# Out:
# ('17.15.11', 4738.673366834171)

# %% [markdown]
# ## Compare "Sports" and "Comady", how many days that there are more total daily views of VDO in "Sports" category than in "Comady" category?

# %%
# Assuming 'category_id' corresponds to categories, with 'Sports' and 'Comedy' having specific IDs
# Replace these IDs with the actual ones corresponding to 'Sports' and 'Comedy' in your DataFrame
sports_category_id = 17  # Example ID for Sports, replace with actual ID
comedy_category_id = 23  # Example ID for Comedy, replace with actual ID

# Filtering the DataFrame for Sports and Comedy categories
sports_df = df[df['category_id'] == sports_category_id]
comedy_df = df[df['category_id'] == comedy_category_id]

# Grouping by trending date and summing views for each category
sports_views = sports_df.groupby('trending_date')['views'].sum()
comedy_views = comedy_df.groupby('trending_date')['views'].sum()

# Combining the two series into a DataFrame
combined_views = pd.DataFrame({'Sports': sports_views, 'Comedy': comedy_views})

# Counting the days where Sports category has more views than Comedy category
days_more_sports_views = (combined_views['Sports'] > combined_views['Comedy']).sum()

days_more_sports_views
# Out:
# 49

# %% [markdown]
# ## 7. pandas series -> when select single column of pandas series, it is pandas series, when select multiples column, it is pandas dataframe

# %%
print(type(df_noduplicate))
print(type(df_noduplicate.loc[:, ['channel_title', 'publish_time']]))
print(type(df_noduplicate.iloc[:, 3:5]))
print()

print(type(df_noduplicate['publish_time']))
print(type(df_noduplicate.iloc[:, 3]))

df_noduplicate.loc[:, ['channel_title', 'publish_time']].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
#                 channel_title              publish_time
# 0                  John Lewis  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos  2017-11-13T01:45:13.000Z

# %%
df_noduplicate['publish_time']
# Out:
# 0        2017-11-10T07:38:29.000Z
# 1        2017-11-12T06:24:44.000Z
# 2        2017-11-10T17:00:03.000Z
# 3        2017-11-13T02:30:38.000Z
# 4        2017-11-13T01:45:13.000Z
#                    ...
# 38911    2018-05-09T07:00:01.000Z
# 38912    2018-05-11T17:09:16.000Z
# 38913    2018-05-08T11:05:08.000Z
# 38914    2018-05-08T20:32:32.000Z
# 38915    2018-05-11T04:06:35.000Z
# Name: publish_time, Length: 38745, dtype: object

# %%
print(type(df_noduplicate))
print(type(df.isna()))
print(type(df.isna().mean()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
print(type(df_noduplicate['channel_title']))
print()
df_noduplicate['channel_title']
# Out:
# <class 'pandas.core.series.Series'>
# 0                        John Lewis
# 1               Saturday Night Live
# 2                        EminemVEVO
# 3        Salford City Football Club
# 4                  Cute Girl Videos
#                     ...
# 38911           EnriqueIglesiasVEVO
# 38912               Jacob Sartorius
# 38913                    Anne-Marie
# 38914       Eurovision Song Contest
# 38915                SuperDuperKyle
# Name: channel_title, Length: 38745, dtype: object

# %% [markdown]
# ## 8. create dataframe and series

# %%
import pandas as pd

# a simple list
list = [1,2,3,4,5]

# create series form a list
ser = pd.Series(list)
print(type(ser))
print(ser)
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
filtered = ser[ser > 3]
filtered_index = ser[ser > 3].index

print(type(filtered))
print(filtered)
print()

print(type(filtered_index))
print(filtered_index)
print()

print(filtered_index[0])
# Out:
# <class 'pandas.core.series.Series'>
# 3    4
# 4    5
# dtype: int64
#
# <class 'pandas.core.indexes.base.Index'>
# Index([3, 4], dtype='int64')
#
# 3

# %% [markdown]
# search command : create dataframe pandas
#
# link : https://www.geeksforgeeks.org/different-ways-to-create-pandas-dataframe/

# %%
list1 = [1,2,3,4,5]
list2 = [5,4,3,2,1]

list_of_tuples = list(zip(list1, list2))
 
# Assign data to tuples.
list_of_tuples
 
 
# Converting lists of tuples into
# pandas Dataframe.
df = pd.DataFrame(list_of_tuples,
                  columns=['list1', 'list2'])
df
# Out:
#    list1  list2
# 0      1      5
# 1      2      4
# 2      3      3
# 3      4      2
# 4      5      1

# %% [markdown]
# ## 9. dataframe.apply and lamda function, create dataframe, statistic (quantile, percentile)

# %% [markdown]
# lamda function -> params, return

# %%
x = lambda a : a + 10
print(x(5))
# Out:
# 15

# %%
x = lambda a, b : a * b
print(x(5, 6))
# Out:
# 30

# %%
# Import pandas library
import pandas as pd

# initialize list of lists
data = [['tom', 10], ['nick', 15], ['juli', 14], ['aug', 12], ['tnn', 35]]

# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['Name', 'Age'])

df
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14
# 3   aug   12
# 4   tnn   35

# %%
Q1 = df['Age'].quantile(0.75)
Q1
# Out:
# 15.0

# %%
df['Age'] = df['Age'].apply(lambda x : min(Q1*2, x))

# %%
df
# Out:
#    Name   Age
# 0   tom  10.0
# 1  nick  15.0
# 2  juli  14.0
# 3   aug  12.0
# 4   tnn  30.0
